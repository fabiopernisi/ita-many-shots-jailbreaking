# %%
import json

from  src.nll_helper import process_and_plot_nll_dataframes

# %%
gemma2b = json.load(open('Results_NLL/Gemma2b/FINAL_NLL_64_shots.json'))['google/gemma-2b']
gemma7b = json.load(open('Results_NLL/Gemma7b/FINAL_NLL_64_shots.json'))['google/gemma-7b']
qwen4b = json.load(open('Results_NLL/Qwen4b/FINAL_NLL_64_shots.json'))['Qwen/Qwen1.5-4B']
qwen7b = json.load(open('Results_NLL/Qwen7b/FINAL_NLL_64_shots.json'))['Qwen/Qwen1.5-7B']
llama3 = json.load(open('Results_NLL/Llama3/FINAL_NLL_64_shots.json'))['meta-llama/Meta-Llama-3-8B']
mistral = json.load(open('Results_NLL/Mistral7b/FINAL_NLL_128_shots.json'))['mistralai/Mistral-7B-v0.3']

# %%
models = [qwen4b, qwen7b, mistral, llama3, gemma2b, gemma7b]
titles = ['Qwen1.5 4B', 'Qwen1.5 7B', 'Mistral 7B', 'Llama3 8B', 'Gemma 2B', 'Gemma 7B']
num_shot_values_list = [
    ["1", "2", "4", "8", "16", "32", "64"],
    ["1", "2", "4", "8", "16", "32", "64"],
    ["1", "2", "4", "8", "16", "32", "64", "128"],
    ["1", "2", "4", "8", "16", "32"],
    ["1", "2", "4", "8", "16", "32"],
    ["1", "2", "4", "8", "16", "32"]
]

# %%
process_and_plot_nll_dataframes(models, titles, num_shot_values_list)
